# %% [markdown]
# # IMPORT SEABORN

# %%
import seaborn as sns

# %% [markdown]
# # IMPORTING MATPLOTLIB AS WELL FOR A LIL COMPARISON AHEAD

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # PLOTTING A BASIC LINEAR GRAPH USING BOTH LIBRARIES

# %%
a = [1,2,3,4]
b = [2,4,6,8]

plt.plot(a,b, color = "green")
plt.show()

# %%
a = [1,2,3,4]
b = [2,4,6,8]

sns.lineplot(x = a, y = b)
plt.show()

# %% [markdown]
# # HOW TO USE PANDA'S DATAFRAME WITH SEABORN TO CREATE A LINEAR PLOT

# %% [markdown]
# ##### Use the same values of the keys in the dataframe for the x and y values in the lineplot() method's parameter. Otherwise it would raise a value error.

# %%
import pandas as pd

a = [1,2,3,4]
b = [2,4,6,8]

df = pd.DataFrame({"X-axis": a, "Y-axis": b})
sns.lineplot(x = "X-axis", y = "Y-axis", data = df)
plt.show()

# %% [markdown]
# # USING AN EXAMPLE DATASET TO PLOT A LINEAR GRAPH

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = sns.load_dataset("penguins")

sns.lineplot(x = "bill_length_mm", y = "flipper_length_mm", data = df)
plt.show()

# %% [markdown]
# # HOW TO PLOT CATEGORICAL PLOTS WITH SEABORN

# %% [markdown]
# ##### To achieve this, we assign the hue parameter of seaborn's lineplot method the value of the notion which is segregated into categories. For example, sex can be segregated into male and female. This will show the desired plot with the keys to identify the categories as well.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = sns.load_dataset("penguins")

sns.lineplot(x = "bill_length_mm", y = "flipper_length_mm", data = df, hue = "sex")
plt.show()

# %% [markdown]
# # HOW TO CHANGE THE COLOR OF LINES IN THE PLOT
#
# ##### Seaborn provides us with "palette" attribute in the lineplot() module which could be assigned a value to change the color of the lines. "rocket_r" is one of the many palettes that seaborn provides us with

# %%
sns.lineplot(x = "bill_length_mm", y = "flipper_length_mm", data = df, hue = "sex", palette = "rocket_r")
plt.show()

# %% [markdown]
# # HOW TO ADD MARKERS TO THE GRAPH TO IDENTIFY THE CATEGORIES EASILY
#
# ##### We need to harness the style and markers attribute in the lineplot() module for this purpose

# %%
sns.lineplot(x = "bill_length_mm", y = "flipper_length_mm", data = df, hue = "sex", palette = "rocket_r", style = "sex", markers = ["o", ">"])
plt.show()

# %% [markdown]
# # HOW TO ADD GRID TO THE GRAPH FOR MORE DETAILED PRESENTATION AND CHANGE THE NAME OF X AND Y AXIS LABELS
#
# ##### The same grid() and xlabel() and ylabel() module of matplotlib.pyplot are used for creating grids in the diagram and overwriting the names of the x and y labels respectively

# %%
sns.lineplot(x = "bill_length_mm", y = "flipper_length_mm", data = df, hue = "sex", palette = "rocket_r", style = "sex", markers = ["o", ">"])
plt.grid()
plt.xlabel("Bill Length")
plt.ylabel("Flipper Length")
plt.show()

# %% [markdown]
# # HOW TO ADD TITLE TO THE DIAGRAM
#
# ##### The title() method of matplotlib.pyplot is used for this purpose

# %%
sns.lineplot(x = "bill_length_mm", y = "flipper_length_mm", data = df, hue = "sex", palette = "rocket_r", style = "sex", markers = ["o", ">"])
plt.grid()
plt.title("Bill Length and Flipper Length wrt Sex")
plt.xlabel("Bill Length")
plt.ylabel("Flipper Length")
plt.show()

# %% [markdown]
# ###### If you do not want to pass in the entire dataframe as a value to the data attribute in the lineplot() method, you could also do this

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = sns.load_dataset("penguins")

sns.lineplot(x = df.bill_length_mm, y = df.flipper_length_mm, hue = df.sex, palette = "rocket_r", style = df.sex, markers = ["o", ">"])
plt.grid()
plt.show()

# %% [markdown]
# # HOW TO DRAW A BAR PLOT USING SEABORN
#
# ##### If you want to assign the data attribute the value of entire dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = sns.load_dataset("penguins")

sns.barplot(x = "island" , y = "bill_length_mm", data = df, palette = "rocket_r")

plt.grid()
plt.show()

# %% [markdown]
# ##### If you do not want to assign the data attribute the value of entire dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = sns.load_dataset("penguins")

sns.barplot(x = df.island, y = df.bill_length_mm, palette = "rocket_r")

plt.grid()
plt.show()

# %% [markdown]
# ##### Here too, you could use the hue attribute to segregate the data with respect to categories of a notion.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = sns.load_dataset("penguins")

sns.barplot(x = df.island, y = df.bill_length_mm, palette = "rocket_r", hue = df.sex)

plt.grid()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = sns.load_dataset("penguins")

sns.barplot(x = "island" , y = "bill_length_mm", data = df, palette = "rocket_r", hue = "sex")

plt.grid()
plt.show()

# %% [markdown]
# # ORDER AND HUE_ORDER ATTRIBUTES
#
# ##### Running the above code furnishes us with a diagram in which the islands are shown as follows on the x axis: Torgersen, Biscoe, and Dream. If we want to alter this order, we could use order attribute.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = sns.load_dataset("penguins")

sns.barplot(x = "island" , y = "bill_length_mm", data = df, palette = "rocket_r", hue = "sex", order = ["Dream","Biscoe","Torgersen"])

plt.grid()
plt.show()

# %% [markdown]
# ##### Similarly if we want to alter the order of the hue i.e what is displayed first male or female penguin in the diagram, we could do that using hue_order attribute

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = sns.load_dataset("penguins")

sns.barplot(x = "island" , y = "bill_length_mm", data = df, palette = "rocket_r", hue = "sex", order = ["Dream","Biscoe","Torgersen"], hue_order = ["Male","Female"])

plt.grid()
plt.show()

# %% [markdown]
# # COLOR ATTRIBUTE FOR BAR PLOTS
#
# ##### If you want to change the color of all the bars in the diagram to a specific color, you could use the color attribute to do so. However, one of the segregated category would receive a default color. On the contrary if you want to assign different color to different bars, then harness the palette attribute instead.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = sns.load_dataset("penguins")

sns.barplot(x = "island" , y = "bill_length_mm", data = df, color = "cyan", hue = "sex", order = ["Dream","Biscoe","Torgersen"], hue_order = ["Female", "Male"])

plt.grid()
plt.show()

# %% [markdown]
# # SATURATION ATTRIBUTE FOR BAR PLOTS
#
# ##### You could modify the color of the diagram further by modifying the saturation attribute

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = sns.load_dataset("penguins")

sns.barplot(x = "island" , y = "bill_length_mm", data = df, color = "cyan", saturation = 0.1, hue = "sex", order = ["Dream","Biscoe","Torgersen"], hue_order = ["Female", "Male"])

plt.grid()
plt.show()

# %% [markdown]
# # HOW TO PLOT A HISTOGRAM USING SEABORN LIBRARY
#
# ##### Either method could be used

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = sns.load_dataset("penguins")

sns.displot(df["flipper_length_mm"])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = sns.load_dataset("penguins")

sns.displot(df.flipper_length_mm)
plt.show()

# %% [markdown]
# # HOW TO ADJUST THE INTERVALS OF THE HISTOGRAM USING THE BINS ATTRIBUTE

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = sns.load_dataset("penguins")

sns.displot(df["flipper_length_mm"], bins = [170,180,190,200,210,220,230])
plt.grid()
plt.show()

# %% [markdown]
# # HOW TO ADJUST THE COLOR OF THE HISTOGRAM USING THE COLOR ATTRIBUTE

# %%
sns.displot(df["flipper_length_mm"], bins = [170,180,190,200,210,220,230], color = "cyan")
plt.grid()
plt.show()

# %% [markdown]
# # HOW TO DISPLAY THE KDE OF THE HISTOGRAM

# %%
sns.displot(df["flipper_length_mm"], bins = [170,180,190,200,210,220,230], color = "cyan", kde = True)
plt.grid()
plt.show()
